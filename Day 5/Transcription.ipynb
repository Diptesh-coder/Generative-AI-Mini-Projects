# %% [markdown]
# Installing Libraries

# %%
! pip install groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.3/138.3 kB 5.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# importing os, json and groq

# %%
import os
import json
from groq import Groq

# %% [markdown]
# **Initializing the Groq client**

# %%
client = Groq(api_key="YOUR_GROQ_API_KEY")

# %% [markdown]
# Specifying the path to the audio file

# %%
filename = "/content/harvard.wav" # Path to your audio file

# %% [markdown]
# Opening the audio file

# %%
with open(filename, "rb") as file:
    # Create a transcription of the audio file
    transcription = client.audio.transcriptions.create(
      file=file, # Required audio file
      model="whisper-large-v3-turbo", # Required model to use for transcription
      prompt="Specify context or spelling",  # Optional
      response_format="verbose_json",  # Optional
      timestamp_granularities = ["word", "segment"], # Optional (must set response_format to "json" to use and can specify "word", "segment" (default), or both)
      language="en",  # Optional
      temperature=0.0  # Optional
    )

# %% [markdown]
# Printing the transcription result

# %%
    print(json.dumps(transcription, indent=2, default=str))

    mytranscription=json.dumps(transcription, indent=2, default=str)

    print(mytranscription)
# Out:
# "Transcription(text=' The stale smell of old beer lingers It takes heat to bring out the odor A cold dip restores health and zest A salt pickle tastes fine with ham Tacos al pastor are my favorite A zestful food is the hot cross bun', task='transcribe', language='English', duration=18.35, words=[{'word': 'The', 'start': 1.32, 'end': 1.42}, {'word': 'stale', 'start': 1.42, 'end': 1.84}, {'word': 'smell', 'start': 1.84, 'end': 2.18}, {'word': 'of', 'start': 2.18, 'end': 2.44}, {'word': 'old', 'start': 2.44, 'end': 2.72}, {'word': 'beer', 'start': 2.72, 'end': 3}, {'word': 'lingers', 'start': 3, 'end': 3.6}, {'word': 'It', 'start': 4.34, 'end': 4.5}, {'word': 'takes', 'start': 4.5, 'end': 4.84}, {'word': 'heat', 'start': 4.84, 'end': 5.1}, {'word': 'to', 'start': 5.1, 'end': 5.34}, {'word': 'bring', 'start': 5.34, 'end': 5.54}, {'word': 'out', 'start': 5.54, 'end': 5.72}, {'word': 'the', 'start': 5.72, 'end': 5.88}, {'word': 'odor', 'start': 5.88, 'end': 6.16}, {'word': 'A', 'start': 6.
# ...

# %%
mytranscription=transcription.text
print(mytranscription)
# Out:
#  The stale smell of old beer lingers It takes heat to bring out the odor A cold dip restores health and zest A salt pickle tastes fine with ham Tacos al pastor are my favorite A zestful food is the hot cross bun

# %%
chat_completion = client.chat.completions.create(
    messages=[
        # Set an optional system message. This sets the behavior of the
        # assistant and can be used to provide specific instructions for
        # how it should behave throughout the conversation.
        {
            "role": "system",
            "content": "Reply like a boss."
        },
        # Set a user message for the assistant to respond to.
        {
            "role": "user",
            "content": "Hello. How are You?",
        }
    ],

    # The language model which will generate the completion.
    model="llama-3.3-70b-versatile",

    temperature=2.0,

)


# Print the completion returned by the LLM.
print(chat_completion.choices[0].message.content)
# Out:
# I'm doing fantastic, thanks for asking. Just ready to tackle any questions or tasks you've got for me. What can I help you with today?

# %% [markdown]
# API Key:- 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

# %% [markdown]
# 1. Installing groq

# %%
# !pip install groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.3/138.3 kB 2.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# 2. Importing Groq, base64 and os

# %%
from groq import Groq
import base64
import os

# %% [markdown]
# 3. Function to encode the image

# %%
def encode_image(image_path):
  with open(image_path, "rb") as image_file:
    return base64.b64encode(image_file.read()).decode('utf-8')

# %% [markdown]
# 4. Path to your image

# %%
image_path = "/content/Receipt.jpg"

# %% [markdown]
# 5. Getting the base64 string

# %%
base64_image = encode_image(image_path)

client = Groq(api_key="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")

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "Extract the contents in tabular form just like an accountant."},
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{base64_image}",
                    },
                },
            ],
        }
    ],
    model="meta-llama/llama-4-scout-17b-16e-instruct",
)

# %% [markdown]
# 6. Printing the output

# %%
print(chat_completion.choices[0].message.content)
# Out:
# **Receipt Details**
#
# The receipt from Bella Pasta is presented in a tabular form as follows:
#
# ### **Receipt Information**
#
# | **Category** | **Description** | **Amount** |
# | --- | --- | --- |
# | Server | PM BAR P | - |
# | Check # | 4 | - |
# | Date | 08/09/19 | - |
# | Time | 4:28 PM | - |
# | Table # | 21 | - |
#
# ### **Order Details**
#
# | **Item** | **Quantity** | **Unit Price** | **Total** |
# | --- | --- | --- | --- |
# | Steak Tip Skewers | - | $12.99 | $12.99 |
# | Piatto Borgonzola | - | $12.99 | $12.99 |
# | Root Beer | - | $2.50 | $2.50 |
#
# ### **Subtotal, Tax, and Total**
#
# | **Category** | **Amount** |
# | --- | --- |
# | Subtotal | $28.48 |
# | Tax | $2.28 |
# | **Total** | **$30.76** |
